# %%
import pandas as pd
import datetime
import numpy as np
import matplotlib.pyplot as plt
import ast
from lightgbm import LGBMClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
df = pd.read_csv(r'../../../data/2022-09-15/listings.csv')

def data_cleanup(df):

    df.dropna(how='all', axis=1, inplace=True) #drop empty cols

    number_looking_strings = ['id', 'scrape_id', 'host_id']
    for col in number_looking_strings:
        df[col] = df[col].astype("string")

    df['host_response_rate'] = df['host_response_rate'].str.replace("%","").astype(float)/100 #previously a percentage as a string
    df['host_acceptance_rate'] = df['host_acceptance_rate'].str.replace("%","").astype(float)/100 #previously a percentage as a string
    df['price'] = df['price'].str.replace(r'[$,]',"").astype(float) #previosuly represented as a string

    date_cols = ['last_scraped', 'host_since', 'calendar_last_scraped', 'first_review', 'last_review']
    for col in date_cols:
        df[col] = pd.to_datetime(df[col], format=r'%Y-%m-%d')

    for col in df.columns:
        if df[col][0] == "f" or df[col][0] == "t": #if first record is "t" or "f" we're going to convert to bool - still should spot check after just incase first record of bool is null
            df[col] = df[col].str.replace("f", "0")
            df[col] = df[col].str.replace("t", "1")
            try: ## int can't hold nulls so if the conversion fails due to a value error, convert to float instead
                df[col] = df[col].astype(int)
            except ValueError:
                df[col] = df[col].astype(float)


    remaining_string_cols = df.select_dtypes(include=["object"]).columns #all remaining object columns are strings so I'm explicitly setting them to be
    for col in remaining_string_cols:
        df[col] = df[col].astype('string')

    list_string_cols = ['host_verifications', 'amenities'] #these 2 columns are string lists so I'm converting them back to object just so I remember to handle them differently
    for col in list_string_cols:
        df[col] = df[col].astype('object')

    return df

df = data_cleanup(df)

def amenity_feature_engineering(df):
    df['amenities_count'] = 0
    df['amenities_length'] = 0
    df['amenities_avg_length_per_amenity'] = 0.0
    for x in range(0, len(df['amenities'])):
        df['amenities_count'][x] = len(ast.literal_eval(df['amenities'][x]))
        df['amenities_length'][x] = len(df['amenities'][x])
        df['amenities_avg_length_per_amenity'][x] = df['amenities_length'][x]/df['amenities_count'][x]
        if df['amenities_avg_length_per_amenity'][x] == np.inf: #if infinite set to zero
            df['amenities_avg_length_per_amenity'][x] = 0
    return df
    
df = amenity_feature_engineering(df)
# Out:
# C:\Users\Neo\AppData\Local\Temp\ipykernel_21264\3009668494.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['price'] = df['price'].str.replace(r'[$,]',"").astype(float) #previosuly represented as a string
# C:\Users\Neo\AppData\Local\Temp\ipykernel_21264\3009668494.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['amenities_count'][x] = len(ast.literal_eval(df['amenities'][x]))
# C:\Users\Neo\AppData\Local\Temp\ipykernel_21264\3009668494.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['amenities_length'][x] = len(df['amenities'][x])
# C:\Users\Neo\AppData\Local\Temp\ipykernel_21264\3009668494.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['amenities_avg_length_per_amenity'][x] = df['amenities_length'][x]/df['amenities_count'][x]
# C:\Users\Neo\AppData\Local\Temp\ipykernel_21264\3009668494.py:48: RuntimeWarning: divide by zero encountered in longlong_scalars
#   df['amenities_avg_length_per_amenity'][x] = df['amenities_length'][x]/df['amenities_count'][x]
# C:\Users\Neo\AppData\Local\Temp\ipykernel_21264\3009668494.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['amenities_avg_length_per_amenity'][x] = 0

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7733 entries, 0 to 7732
# Data columns (total 74 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            7733 non-null   string
#  1   listing_url                                   7733 non-null   string
#  2   scrape_id                                     7733 non-null   string
#  3   last_scraped                                  7733 non-null   datetime64[ns]
#  4   source                                        7733 non-null   string
#  5   name                                          7733 non-null   string
#  6   description                                   7691 non-null   string
#  7   neighborhood_overview                         5502 non-null   string
#  8   picture_url                                   7733 non-null   string
#  9   host_id                                       7733 non-null   string
#  10  host_url                                      7733 non-null   string
#  11  host_name                                     7653 non-null   string
#  12  host_since                                    7653 non-null   datetime64[ns]
#  13  host_location                                 6556 non-null   string
#  14  host_about                                    5383 non-null   string
#  15  host_response_time                            6889 non-null   string
#  16  host_response_rate                            6889 non-null   float64
#  17  host_acceptance_rate                          7126 non-null   float64
#  18  host_is_superhost                             7732 non-null   float64
#  19  host_thumbnail_url                            7653 non-null   string
#  20  host_picture_url                              7653 non-null   string
#  21  host_neighbourhood                            5321 non-null   string
#  22  host_listings_count                           7653 non-null   float64
#  23  host_total_listings_count                     7653 non-null   float64
#  24  host_verifications                            7733 non-null   object
#  25  host_has_profile_pic                          7653 non-null   float64
#  26  host_identity_verified                        7653 non-null   float64
#  27  neighbourhood                                 5502 non-null   string
#  28  neighbourhood_cleansed                        7733 non-null   string
#  29  latitude                                      7733 non-null   float64
#  30  longitude                                     7733 non-null   float64
#  31  property_type                                 7733 non-null   string
#  32  room_type                                     7733 non-null   string
#  33  accommodates                                  7733 non-null   int64
#  34  bathrooms_text                                7730 non-null   string
#  35  bedrooms                                      7404 non-null   float64
#  36  beds                                          7696 non-null   float64
#  37  amenities                                     7733 non-null   object
#  38  price                                         7733 non-null   float64
#  39  minimum_nights                                7733 non-null   int64
#  40  maximum_nights                                7733 non-null   int64
#  41  minimum_minimum_nights                        7732 non-null   float64
#  42  maximum_minimum_nights                        7732 non-null   float64
#  43  minimum_maximum_nights                        7732 non-null   float64
#  44  maximum_maximum_nights                        7732 non-null   float64
#  45  minimum_nights_avg_ntm                        7732 non-null   float64
#  46  maximum_nights_avg_ntm                        7732 non-null   float64
#  47  has_availability                              7733 non-null   int32
#  48  availability_30                               7733 non-null   int64
#  49  availability_60                               7733 non-null   int64
#  50  availability_90                               7733 non-null   int64
#  51  availability_365                              7733 non-null   int64
#  52  calendar_last_scraped                         7733 non-null   datetime64[ns]
#  53  number_of_reviews                             7733 non-null   int64
#  54  number_of_reviews_ltm                         7733 non-null   int64
#  55  number_of_reviews_l30d                        7733 non-null   int64
#  56  first_review                                  6824 non-null   datetime64[ns]
#  57  last_review                                   6824 non-null   datetime64[ns]
#  58  review_scores_rating                          6824 non-null   float64
#  59  review_scores_accuracy                        6813 non-null   float64
#  60  review_scores_cleanliness                     6813 non-null   float64
#  61  review_scores_checkin                         6812 non-null   float64
#  62  review_scores_communication                   6813 non-null   float64
#  63  review_scores_location                        6812 non-null   float64
#  64  review_scores_value                           6812 non-null   float64
#  65  instant_bookable                              7733 non-null   int32
#  66  calculated_host_listings_count                7733 non-null   int64
#  67  calculated_host_listings_count_entire_homes   7733 non-null   int64
#  68  calculated_host_listings_count_private_rooms  7733 non-null   int64
#  69  calculated_host_listings_count_shared_rooms   7733 non-null   int64
#  70  reviews_per_month                             6824 non-null   float64
#  71  amenities_count                               7733 non-null   int64
#  72  amenities_length                              7733 non-null   int64
#  73  amenities_avg_length_per_amenity              7733 non-null   float64
# dtypes: datetime64[ns](5), float64(27), int32(2), int64(16), object(2), string(22)
# memory usage: 4.3+ MB

# %%
def split_dates(df):
    date_cols = df.select_dtypes(include=["datetime64[ns]"]).columns
    for col in date_cols:
        df[col + "_Month"] = df[col].dt.month
        df[col + "_Day"] = df[col].dt.day
        df[col + "_Year"] = df[col].dt.year
        df.drop(columns=[col], inplace=True)
split_dates(df)

# %%
#drop columns with primarlity unique values - this will take care of things like ids, urls, descriptions, etc
drop_list = []
string_cols = df.select_dtypes(include=["object","string"]).columns
for col in string_cols:
    if len(df[col].value_counts()) > 1000:
        drop_list.append(col)

print(drop_list, "getting dropped.")
df.drop(columns=drop_list, inplace=True)


#also drop neighborhood because there's a cleansed column with this
df.drop(columns=['neighbourhood'], inplace=True)
# Out:
# ['id', 'listing_url', 'name', 'description', 'neighborhood_overview', 'picture_url', 'host_id', 'host_url', 'host_name', 'host_about', 'host_thumbnail_url', 'host_picture_url', 'amenities'] getting dropped.

# %%
df['host_is_superhost'].isna().sum() #only one - so lets drop
df.drop(df[df['host_is_superhost'].isna()].index, inplace=True)

# %%
# Separate target variable and feature columns
target = df["host_is_superhost"]
features = df.drop(["host_is_superhost"], axis=1)

# Impute missing values using mode for categorical columns and median for numerical columns
cat_columns = features.select_dtypes(include=["string","object"]).columns
num_columns = features.select_dtypes(include="number").columns

# Replace missing values in the categorical columns with the most frequent value
for col in cat_columns:
        features[col].fillna("⍼", inplace=True)

# Replace missing values in the numerical columns with the median value
for col in num_columns:
    features[col].fillna(features[col].mean(), inplace=True)

features = pd.get_dummies(features, dummy_na=True)

# %%
import re
features = features.rename(columns = lambda x:re.sub('[^A-Za-z0-9_]+', '', x))
features.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7732 entries, 0 to 7732
# Data columns (total 737 columns):
#  #    Column                                                  Dtype
# ---   ------                                                  -----
#  0    host_response_rate                                      float64
#  1    host_acceptance_rate                                    float64
#  2    host_listings_count                                     float64
#  3    host_total_listings_count                               float64
#  4    host_has_profile_pic                                    float64
#  5    host_identity_verified                                  float64
#  6    latitude                                                float64
#  7    longitude                                               float64
#  8    accommodates                                            int64
#  9    bedrooms                                                float64
#  10   beds                                                    float64
#  11   price                                                   float64
#  12   minimum_nights                                          int64
#  13   maximum_nights                                          int64
#  14   minimum_minimum_nights                                  float64
#  15   maximum_minimum_nights                                  float64
#  16   minimum_maximum_nights                                  float64
#  17   maximum_maximum_nights                                  float64
#  18   minimum_nights_avg_ntm                                  float64
#  19   maximum_nights_avg_ntm                                  float64
#  20   has_availability                                        int32
#  21   availability_30                                         int64
#  22   availability_60                                         int64
#  23   availability_90                                         int64
#  24   availability_365                                        int64
#  25   number_of_reviews                                       int64
#  26   number_of_reviews_ltm                                   int64
#  27   number_of_reviews_l30d                                  int64
#  28   review_scores_rating                                    float64
#  29   review_scores_accuracy                                  float64
#  30   review_scores_cleanliness                               float64
#  31   review_scores_checkin                                   float64
#  32   review_scores_communication                             float64
#  33   review_scores_location                                  float64
#  34   review_scores_value                                     float64
#  35   instant_bookable                                        int32
#  36   calculated_host_listings_count                          int64
#  37   calculated_host_listings_count_entire_homes             int64
#  38   calculated_host_listings_count_private_rooms            int64
#  39   calculated_host_listings_count_shared_rooms             int64
#  40   reviews_per_month                                       float64
#  41   amenities_count                                         int64
#  42   amenities_length                                        int64
#  43   amenities_avg_length_per_amenity                        float64
#  44   last_scraped_Month                                      int64
#  45   last_scraped_Day                                        int64
#  46   last_scraped_Year                                       int64
#  47   host_since_Month                                        float64
#  48   host_since_Day                                          float64
#  49   host_since_Year                                         float64
#  50   calendar_last_scraped_Month                             int64
#  51   calendar_last_scraped_Day                               int64
#  52   calendar_last_scraped_Year                              int64
#  53   first_review_Month                                      float64
#  54   first_review_Day                                        float64
#  55   first_review_Year                                       float64
#  56   last_review_Month                                       float64
#  57   last_review_Day                                         float64
#  58   last_review_Year                                        float64
#  59   scrape_id_20220915162211                                uint8
#  60   scrape_id_NA                                            uint8
#  61   source_cityscrape                                       uint8
#  62   source_previousscrape                                   uint8
#  63   source_NA                                               uint8
#  64   host_location_AlgoodTN                                  uint8
#  65   host_location_AmarilloTX                                uint8
#  66   host_location_AndersonvilleTN                           uint8
#  67   host_location_AnnArborMI                                uint8
#  68   host_location_AntiochTN                                 uint8
#  69   host_location_AppleValleyCA                             uint8
#  70   host_location_ArlingtonTN                               uint8
#  71   host_location_ArlingtonTX                               uint8
#  72   host_location_ArvadaCO                                  uint8
#  73   host_location_AshevilleNC                               uint8
#  74   host_location_AthensTN                                  uint8
#  75   host_location_AtlantaGA                                 uint8
#  76   host_location_AtlanticBeachFL                           uint8
#  77   host_location_AustinTX                                  uint8
#  78   host_location_BaltimoreMD                               uint8
#  79   host_location_BerkeleyCA                                uint8
#  80   host_location_BethpageTN                                uint8
#  81   host_location_BeverlyHillsCA                            uint8
#  82   host_location_BiloxiMS                                  uint8
#  83   host_location_BlufftonSC                                uint8
#  84   host_location_BocaRatonFL                               uint8
#  85   host_location_BostonMA                                  uint8
#  86   host_location_BowlingGreenKY                            uint8
#  87   host_location_BozemanMT                                 uint8
#  88   host_location_BradentonFL                               uint8
#  89   host_location_BransonMO                                 uint8
#  90   host_location_BrentwoodTN                               uint8
#  91   host_location_BuffaloMN                                 uint8
#  92   host_location_CaldwellOH                                uint8
#  93   host_location_CaliforniaUnitedStates                    uint8
#  94   host_location_ChandlerAZ                                uint8
#  95   host_location_CharlestonSC                              uint8
#  96   host_location_CharlotteNC                               uint8
#  97   host_location_ChattanoogaTN                             uint8
#  98   host_location_ChicagoIL                                 uint8
#  99   host_location_CincinnatiOH                              uint8
#  100  host_location_ClarksvilleTN                             uint8
#  101  host_location_ClawsonMI                                 uint8
#  102  host_location_ClearwaterFL                              uint8
#  103  host_location_ClovisCA                                  uint8
#  104  host_location_CocoaFL                                   uint8
#  105  host_location_CollegeGroveTN                            uint8
#  106  host_location_ColoradoSpringsCO                         uint8
#  107  host_location_ColoradoUnitedStates                      uint8
#  108  host_location_ColumbiaTN                                uint8
#  109  host_location_ColumbusGA                                uint8
#  110  host_location_ColumbusIN                                uint8
#  111  host_location_ColumbusOH                                uint8
#  112  host_location_CopenhagenDenmark                         uint8
#  113  host_location_CornwallNY                                uint8
#  114  host_location_CovingtonKY                               uint8
#  115  host_location_CreteIL                                   uint8
#  116  host_location_CrombergCA                                uint8
#  117  host_location_DallasTX                                  uint8
#  118  host_location_DankasaIndia                              uint8
#  119  host_location_DelrayBeachFL                             uint8
#  120  host_location_DenverCO                                  uint8
#  121  host_location_DestinFL                                  uint8
#  122  host_location_DeweyIL                                   uint8
#  123  host_location_DunwoodyGA                                uint8
#  124  host_location_DurhamNC                                  uint8
#  125  host_location_EaglevilleTN                              uint8
#  126  host_location_EdmontonCanada                            uint8
#  127  host_location_EmeryvilleCA                              uint8
#  128  host_location_EncinitasCA                               uint8
#  129  host_location_EvanstonIL                                uint8
#  130  host_location_FairfieldNJ                               uint8
#  131  host_location_FlagstaffAZ                               uint8
#  132  host_location_FlintMI                                   uint8
#  133  host_location_FloridaUnitedStates                       uint8
#  134  host_location_FlushingMI                                uint8
#  135  host_location_ForestHillsTN                             uint8
#  136  host_location_FortCollinsCO                             uint8
#  137  host_location_FortLauderdaleFL                          uint8
#  138  host_location_FortMohaveAZ                              uint8
#  139  host_location_FortWorthTX                               uint8
#  140  host_location_FranklinTN                                uint8
#  141  host_location_FresnoCA                                  uint8
#  142  host_location_FulshearTX                                uint8
#  143  host_location_GainesvilleFL                             uint8
#  144  host_location_GallatinTN                                uint8
#  145  host_location_GeorgetownTX                              uint8
#  146  host_location_GoodlettsvilleTN                          uint8
#  147  host_location_GrandRapidsMI                             uint8
#  148  host_location_GreenbrierTN                              uint8
#  149  host_location_GulfShoresAL                              uint8
#  150  host_location_HattiesburgMS                             uint8
#  151  host_location_HawaiiUnitedStates                        uint8
#  152  host_location_HendersonvilleTN                          uint8
#  153  host_location_HermosaBeachCA                            uint8
#  154  host_location_HollisterCA                               uint8
#  155  host_location_HollywoodFL                               uint8
#  156  host_location_HoustonTX                                 uint8
#  157  host_location_HudsonWI                                  uint8
#  158  host_location_HuntingtonBeachCA                         uint8
#  159  host_location_HuntsvilleAL                              uint8
#  160  host_location_IndianapolisIN                            uint8
#  161  host_location_IpswichMA                                 uint8
#  162  host_location_IrvineCA                                  uint8
#  163  host_location_JacksonTN                                 uint8
#  164  host_location_JacksonvilleFL                            uint8
#  165  host_location_JamshedpurIndia                           uint8
#  166  host_location_JerichoVT                                 uint8
#  167  host_location_JerusalemIsrael                           uint8
#  168  host_location_JohnsonCityTN                             uint8
#  169  host_location_KentuckyUnitedStates                      uint8
#  170  host_location_KingstonSpringsTN                         uint8
#  171  host_location_KnoxvilleTN                               uint8
#  172  host_location_KodakTN                                   uint8
#  173  host_location_LaVergneTN                                uint8
#  174  host_location_LagunaNiguelCA                            uint8
#  175  host_location_LakeForestCA                              uint8
#  176  host_location_LakewoodRanchFL                           uint8
#  177  host_location_LampeMO                                   uint8
#  178  host_location_LasVegasNV                                uint8
#  179  host_location_LawrencevilleGA                           uint8
#  180  host_location_LebanonTN                                 uint8
#  181  host_location_LexingtonKY                               uint8
#  182  host_location_LexingtonVA                               uint8
#  183  host_location_LittleRockAR                              uint8
#  184  host_location_LondonUnitedKingdom                       uint8
#  185  host_location_LongBeachCA                               uint8
#  186  host_location_LosAngelesCA                              uint8
#  187  host_location_LosGatosCA                                uint8
#  188  host_location_LouisvilleKY                              uint8
#  189  host_location_MadisonWI                                 uint8
#  190  host_location_ManhattanBeachCA                          uint8
#  191  host_location_MantenoIL                                 uint8
#  192  host_location_McHenryIL                                 uint8
#  193  host_location_MemphisTN                                 uint8
#  194  host_location_MiamiFL                                   uint8
#  195  host_location_MikonosGreece                             uint8
#  196  host_location_MillbraeCA                                uint8
#  197  host_location_MilwaukeeWI                               uint8
#  198  host_location_MissouriUnitedStates                      uint8
#  199  host_location_ModestoCA                                 uint8
#  200  host_location_MorgantownWV                              uint8
#  201  host_location_MountJulietTN                             uint8
#  202  host_location_MtJulietTN                                uint8
#  203  host_location_MurfreesboroTN                            uint8
#  204  host_location_MuskegonMI                                uint8
#  205  host_location_MyrtleBeachSC                             uint8
#  206  host_location_NashvilleTN                               uint8
#  207  host_location_NewOrleansLA                              uint8
#  208  host_location_NewSmyrnaBeachFL                          uint8
#  209  host_location_NewYorkNY                                 uint8
#  210  host_location_NewportBeachCA                            uint8
#  211  host_location_NicevilleFL                               uint8
#  212  host_location_NolensvilleTN                             uint8
#  213  host_location_NorthMyrtleBeachSC                        uint8
#  214  host_location_OakHillTN                                 uint8
#  215  host_location_OakParkIL                                 uint8
#  216  host_location_OakViewCA                                 uint8
#  217  host_location_OaklandCA                                 uint8
#  218  host_location_OrangeCA                                  uint8
#  219  host_location_OrlandoFL                                 uint8
#  220  host_location_PaducahKY                                 uint8
#  221  host_location_PalmSpringsCA                             uint8
#  222  host_location_ParisTN                                   uint8
#  223  host_location_PasoRoblesCA                              uint8
#  224  host_location_PegramTN                                  uint8
#  225  host_location_PembrokePinesFL                           uint8
#  226  host_location_PhiladelphiaPA                            uint8
#  227  host_location_PiscatawayNJ                              uint8
#  228  host_location_PittsburghPA                              uint8
#  229  host_location_PlainCityOH                               uint8
#  230  host_location_PortSaintJohnFL                           uint8
#  231  host_location_PortlandOR                                uint8
#  232  host_location_PortsmouthNH                              uint8
#  233  host_location_ProspectKY                                uint8
#  234  host_location_ProvoUT                                   uint8
#  235  host_location_RaleighNC                                 uint8
#  236  host_location_RanchoCucamongaCA                         uint8
#  237  host_location_RedlandsCA                                uint8
#  238  host_location_RedwoodCityCA                             uint8
#  239  host_location_RegisterGA                                uint8
#  240  host_location_RentonWA                                  uint8
#  241  host_location_RhodeIslandUnitedStates                   uint8
#  242  host_location_RidgelandMS                               uint8
#  243  host_location_RiverviewFL                               uint8
#  244  host_location_RochesterNY                               uint8
#  245  host_location_RockIslandTN                              uint8
#  246  host_location_RockvilleMD                               uint8
#  247  host_location_RoswellGA                                 uint8
#  248  host_location_RoyaltonVT                                uint8
#  249  host_location_SacramentoCA                              uint8
#  250  host_location_SaintPetersburgFL                         uint8
#  251  host_location_SanAntonioTX                              uint8
#  252  host_location_SanDiegoCA                                uint8
#  253  host_location_SanFranciscoCA                            uint8
#  254  host_location_SanJoseCA                                 uint8
#  255  host_location_SanLuisObispoCA                           uint8
#  256  host_location_SanfordNC                                 uint8
#  257  host_location_SantaClaritaCA                            uint8
#  258  host_location_SantaCruzCA                               uint8
#  259  host_location_SarasotaFL                                uint8
#  260  host_location_ScottsdaleAZ                              uint8
#  261  host_location_SeattleWA                                 uint8
#  262  host_location_SebastopolMS                              uint8
#  263  host_location_SemmesAL                                  uint8
#  264  host_location_SeviervilleTN                             uint8
#  265  host_location_SmyrnaTN                                  uint8
#  266  host_location_SomervilleNJ                              uint8
#  267  host_location_SonomaCA                                  uint8
#  268  host_location_SpringHillTN                              uint8
#  269  host_location_SpringfieldMO                             uint8
#  270  host_location_StPetersburgFL                            uint8
#  271  host_location_StAugustineFL                             uint8
#  272  host_location_StLouisMO                                 uint8
#  273  host_location_StatesboroGA                              uint8
#  274  host_location_SunsetSC                                  uint8
#  275  host_location_TacomaWA                                  uint8
#  276  host_location_TallahasseeFL                             uint8
#  277  host_location_TampaFL                                   uint8
#  278  host_location_TennesseeUnitedStates                     uint8
#  279  host_location_TexasUnitedStates                         uint8
#  280  host_location_ThompsonsStationTN                        uint8
#  281  host_location_TorranceCA                                uint8
#  282  host_location_UnitedStates                              uint8
#  283  host_location_UrbandaleIA                               uint8
#  284  host_location_VancouverCanada                           uint8
#  285  host_location_VeniceFL                                  uint8
#  286  host_location_VirginiaUnitedStates                      uint8
#  287  host_location_WashingtonDC                              uint8
#  288  host_location_WayneIL                                   uint8
#  289  host_location_WestlakeVillageCA                         uint8
#  290  host_location_WilliamsburgVA                            uint8
#  291  host_location_WiltonCA                                  uint8
#  292  host_location_WysoxPA                                   uint8
#  293  host_location_                                          uint8
#  294  host_location_NA                                        uint8
#  295  host_response_time_afewdaysormore                       uint8
#  296  host_response_time_withinaday                           uint8
#  297  host_response_time_withinafewhours                      uint8
#  298  host_response_time_withinanhour                         uint8
#  299  host_response_time_                                     uint8
#  300  host_response_time_NA                                   uint8
#  301  host_neighbourhood_12South                              uint8
#  302  host_neighbourhood_AcklenWestgrove                      uint8
#  303  host_neighbourhood_AdairPark                            uint8
#  304  host_neighbourhood_AnaheimResort                        uint8
#  305  host_neighbourhood_Antioch                              uint8
#  306  host_neighbourhood_ArtsDistrict                         uint8
#  307  host_neighbourhood_Astrodome                            uint8
#  308  host_neighbourhood_BarclayDrive                         uint8
#  309  host_neighbourhood_BayPointista                         uint8
#  310  host_neighbourhood_BayView                              uint8
#  311  host_neighbourhood_BeaconSquare                         uint8
#  312  host_neighbourhood_Bellehaven                           uint8
#  313  host_neighbourhood_Bellevue                             uint8
#  314  host_neighbourhood_BellshireTerrace                     uint8
#  315  host_neighbourhood_Belmont                              uint8
#  316  host_neighbourhood_Bluefields                           uint8
#  317  host_neighbourhood_BordeauxArea                         uint8
#  318  host_neighbourhood_BradfordHills                        uint8
#  319  host_neighbourhood_BransfordAvenue                      uint8
#  320  host_neighbourhood_BransonTheatreDistrict               uint8
#  321  host_neighbourhood_BreezeHill                           uint8
#  322  host_neighbourhood_BrentwoodChase                       uint8
#  323  host_neighbourhood_BrickChurchBellshire                 uint8
#  324  host_neighbourhood_Buckhead                             uint8
#  325  host_neighbourhood_BuckroeBeach                         uint8
#  326  host_neighbourhood_BullMountain                         uint8
#  327  host_neighbourhood_CahalStreetGroup                     uint8
#  328  host_neighbourhood_Caldwall                             uint8
#  329  host_neighbourhood_CaneRidge                            uint8
#  330  host_neighbourhood_CanterburyHillCondos                 uint8
#  331  host_neighbourhood_CapitolHill                          uint8
#  332  host_neighbourhood_CarlylePlace                         uint8
#  333  host_neighbourhood_CarmelArtsDesignDistrict             uint8
#  334  host_neighbourhood_CayceHomes                           uint8
#  335  host_neighbourhood_CenterCity                           uint8
#  336  host_neighbourhood_CentralBusinessDistrict              uint8
#  337  host_neighbourhood_CentralCity                          uint8
#  338  host_neighbourhood_CentralEastOakland                   uint8
#  339  host_neighbourhood_CenturyWest                          uint8
#  340  host_neighbourhood_Chapel                               uint8
#  341  host_neighbourhood_CharlotteAmalie                      uint8
#  342  host_neighbourhood_CharlottePark                        uint8
#  343  host_neighbourhood_Charlottecentercity                  uint8
#  344  host_neighbourhood_CharterOak                           uint8
#  345  host_neighbourhood_Chelsea                              uint8
#  346  host_neighbourhood_CherokeePark                         uint8
#  347  host_neighbourhood_Chesapeake                           uint8
#  348  host_neighbourhood_ChestnutHill                         uint8
#  349  host_neighbourhood_ChicagoLoop                          uint8
#  350  host_neighbourhood_CityCenter                           uint8
#  351  host_neighbourhood_ClarkPlace                           uint8
#  352  host_neighbourhood_ClearwaterBeach                      uint8
#  353  host_neighbourhood_Clifton                              uint8
#  354  host_neighbourhood_CliftonSouthwest                     uint8
#  355  host_neighbourhood_CloverlandAcres                      uint8
#  356  host_neighbourhood_CloverlandTownhomesofFredericksburg  uint8
#  357  host_neighbourhood_Clovernook                           uint8
#  358  host_neighbourhood_CollegeHeightsClifton                uint8
#  359  host_neighbourhood_ColumbusPark                         uint8
#  360  host_neighbourhood_CoralWay                             uint8
#  361  host_neighbourhood_CorinnePlace                         uint8
#  362  host_neighbourhood_Cottonport                           uint8
#  363  host_neighbourhood_Crestridge                           uint8
#  364  host_neighbourhood_CroleyWood                           uint8
#  365  host_neighbourhood_CrossTimbers                         uint8
#  366  host_neighbourhood_CulverCity                           uint8
#  367  host_neighbourhood_CurreywoodAcres                      uint8
#  368  host_neighbourhood_DalemereArea                         uint8
#  369  host_neighbourhood_DanaPoint                            uint8
#  370  host_neighbourhood_DaytonaBeachRegency                  uint8
#  371  host_neighbourhood_Deerwood                             uint8
#  372  host_neighbourhood_DesertViewVillage                    uint8
#  373  host_neighbourhood_Donelson                             uint8
#  374  host_neighbourhood_DonelsonHills                        uint8
#  375  host_neighbourhood_Downtown                             uint8
#  376  host_neighbourhood_DowntownAustin                       uint8
#  377  host_neighbourhood_DowntownMiami                        uint8
#  378  host_neighbourhood_DrakePark                            uint8
#  379  host_neighbourhood_EastEnd                              uint8
#  380  host_neighbourhood_EastGermantown                       uint8
#  381  host_neighbourhood_EastNashville                        uint8
#  382  host_neighbourhood_EastNewYork                          uint8
#  383  host_neighbourhood_EastRiversideOltorf                  uint8
#  384  host_neighbourhood_Eastwood                             uint8
#  385  host_neighbourhood_EdgeOfLake                           uint8
#  386  host_neighbourhood_Edgehill                             uint8
#  387  host_neighbourhood_ElmHillAcres                         uint8
#  388  host_neighbourhood_EurekaValley                         uint8
#  389  host_neighbourhood_FANG                                 uint8
#  390  host_neighbourhood_Fairfax                              uint8
#  391  host_neighbourhood_FairlanePark                         uint8
#  392  host_neighbourhood_FiskMeharry                          uint8
#  393  host_neighbourhood_FivePoints                           uint8
#  394  host_neighbourhood_Fondren                              uint8
#  395  host_neighbourhood_FrenchQuarter                        uint8
#  396  host_neighbourhood_FrenchmansBay                        uint8
#  397  host_neighbourhood_FriendsOnFive                        uint8
#  398  host_neighbourhood_Gaslamp                              uint8
#  399  host_neighbourhood_GaslampQuarter                       uint8
#  400  host_neighbourhood_Germantown                           uint8
#  401  host_neighbourhood_Glencliff                            uint8
#  402  host_neighbourhood_Glengarry                            uint8
#  403  host_neighbourhood_Glenwood                             uint8
#  404  host_neighbourhood_Gonzales                             uint8
#  405  host_neighbourhood_GoodlettsvilleHeights                uint8
#  406  host_neighbourhood_GrandviewHeights                     uint8
#  407  host_neighbourhood_GrantPark                            uint8
#  408  host_neighbourhood_GreenHills                           uint8
#  409  host_neighbourhood_Greenville                           uint8
#  410  host_neighbourhood_GreenwayUpperKirby                   uint8
#  411  host_neighbourhood_Greenwood                            uint8
#  412  host_neighbourhood_HadleyPark                           uint8
#  413  host_neighbourhood_HadleyWashington                     uint8
#  414  host_neighbourhood_HailePlantation                      uint8
#  415  host_neighbourhood_Harborview                           uint8
#  416  host_neighbourhood_HaynesArea                           uint8
#  417  host_neighbourhood_HaynesEstates                        uint8
#  418  host_neighbourhood_HaynesPark                           uint8
#  419  host_neighbourhood_HaywoodAcres                         uint8
#  420  host_neighbourhood_HaywoodHeights                       uint8
#  421  host_neighbourhood_HeinPark                             uint8
#  422  host_neighbourhood_Hermitage                            uint8
#  423  host_neighbourhood_HickoryHeights                       uint8
#  424  host_neighbourhood_HickoryValley                        uint8
#  425  host_neighbourhood_HickoryValleyCondos                  uint8
#  426  host_neighbourhood_HighlandsofBrentwood                 uint8
#  427  host_neighbourhood_Hillbrook                            uint8
#  428  host_neighbourhood_Hillcrest                            uint8
#  429  host_neighbourhood_HillsboroWestEnd                     uint8
#  430  host_neighbourhood_HillsboroBelmont                     uint8
#  431  host_neighbourhood_HistoricDistrictNorth                uint8
#  432  host_neighbourhood_HistoricEdgefield                    uint8
#  433  host_neighbourhood_HistoricWaverly                      uint8
#  434  host_neighbourhood_HollywoodSouthCentralBeach           uint8
#  435  host_neighbourhood_HopeGardens                          uint8
#  436  host_neighbourhood_HumberDrive                          uint8
#  437  host_neighbourhood_HurwoodHeights                       uint8
#  438  host_neighbourhood_ImperialPoint                        uint8
#  439  host_neighbourhood_InletBeach                           uint8
#  440  host_neighbourhood_Jeffersonville                       uint8
#  441  host_neighbourhood_Joelton                              uint8
#  442  host_neighbourhood_JonesBuenaVista                      uint8
#  443  host_neighbourhood_KailuaKona                           uint8
#  444  host_neighbourhood_Kapalua                              uint8
#  445  host_neighbourhood_Kauai                                uint8
#  446  host_neighbourhood_KeelingAvenue                        uint8
#  447  host_neighbourhood_KemperHeights                        uint8
#  448  host_neighbourhood_Kingsbury                            uint8
#  449  host_neighbourhood_LagunaBeachEstates                   uint8
#  450  host_neighbourhood_Lakewood                             uint8
#  451  host_neighbourhood_Larkwood                             uint8
#  452  host_neighbourhood_LenoxVillage                         uint8
#  453  host_neighbourhood_Lincolnville                         uint8
#  454  host_neighbourhood_LindaVista                           uint8
#  455  host_neighbourhood_LindridgeMartinManor                 uint8
#  456  host_neighbourhood_LittleItalyUIC                       uint8
#  457  host_neighbourhood_LockelandSprings                     uint8
#  458  host_neighbourhood_Locustwood                           uint8
#  459  host_neighbourhood_LongBeach                            uint8
#  460  host_neighbourhood_Lyndale                              uint8
#  461  host_neighbourhood_Madison                              uint8
#  462  host_neighbourhood_ManskerHeights                       uint8
#  463  host_neighbourhood_Maxwell                              uint8
#  464  host_neighbourhood_McKissackPark                        uint8
#  465  host_neighbourhood_McMurray                             uint8
#  466  host_neighbourhood_Melrose                              uint8
#  467  host_neighbourhood_MelroseHeights                       uint8
#  468  host_neighbourhood_MerryOaks                            uint8
#  469  host_neighbourhood_MetrocenterNorthRhodesPark           uint8
#  470  host_neighbourhood_MiamiBeach                           uint8
#  471  host_neighbourhood_MidWilshire                          uint8
#  472  host_neighbourhood_Midtown                              uint8
#  473  host_neighbourhood_MidtownEast                          uint8
#  474  host_neighbourhood_MileSquare                           uint8
#  475  host_neighbourhood_MiroMeadows                          uint8
#  476  host_neighbourhood_MontgomeryPlace                      uint8
#  477  host_neighbourhood_Morriswood                           uint8
#  478  host_neighbourhood_MusicRow                             uint8
#  479  host_neighbourhood_NapierArea                           uint8
#  480  host_neighbourhood_NashboroVillage                      uint8
#  481  host_neighbourhood_NashboroWoods                        uint8
#  482  host_neighbourhood_NationalHarbor                       uint8
#  483  host_neighbourhood_NewportBeach                         uint8
#  484  host_neighbourhood_NormalStation                        uint8
#  485  host_neighbourhood_NorthBrookhaven                      uint8
#  486  host_neighbourhood_NorthCapitol                         uint8
#  487  host_neighbourhood_NorthCapitolHill                     uint8
#  488  host_neighbourhood_NorthChattanooga                     uint8
#  489  host_neighbourhood_NorthNashville                       uint8
#  490  host_neighbourhood_NorthPhiladelphia                    uint8
#  491  host_neighbourhood_NortheastDurham                      uint8
#  492  host_neighbourhood_NorthgateWaverly                     uint8
#  493  host_neighbourhood_Northside                            uint8
#  494  host_neighbourhood_NorthwestNashville                   uint8
#  495  host_neighbourhood_NorthwestSeattle                     uint8
#  496  host_neighbourhood_NorthwestSide                        uint8
#  497  host_neighbourhood_NorthwestWashington                  uint8
#  498  host_neighbourhood_Nrrebro                              uint8
#  499  host_neighbourhood_OakCliff                             uint8
#  500  host_neighbourhood_Oakhaven                             uint8
#  501  host_neighbourhood_OldHickory                           uint8
#  502  host_neighbourhood_OldTown                              uint8
#  503  host_neighbourhood_Orange                               uint8
#  504  host_neighbourhood_OrmondShores                         uint8
#  505  host_neighbourhood_OzarkHills                           uint8
#  506  host_neighbourhood_ParadiseValleyVillage                uint8
#  507  host_neighbourhood_ParkwoodEstates                      uint8
#  508  host_neighbourhood_PeachtreeCenter                      uint8
#  509  host_neighbourhood_PenningtonBend                       uint8
#  510  host_neighbourhood_PercyPriestWoods                     uint8
#  511  host_neighbourhood_PerryHeights                         uint8
#  512  host_neighbourhood_PiccadillySquare                     uint8
#  513  host_neighbourhood_Polebridge                           uint8
#  514  host_neighbourhood_PorterHeights                        uint8
#  515  host_neighbourhood_PriestLake                           uint8
#  516  host_neighbourhood_PriestLakeMeadows                    uint8
#  517  host_neighbourhood_Quailtrail                           uint8
#  518  host_neighbourhood_QuarryBay                            uint8
#  519  host_neighbourhood_RacquetClubWest                      uint8
#  520  host_neighbourhood_Radnor                               uint8
#  521  host_neighbourhood_RaineyStreet                         uint8
#  522  host_neighbourhood_RanchwoodEstates                     uint8
#  523  host_neighbourhood_Richland                             uint8
#  524  host_neighbourhood_RiverTrace                           uint8
#  525  host_neighbourhood_RollingAcres                         uint8
#  526  host_neighbourhood_Rollingwood                          uint8
#  527  host_neighbourhood_Rosebank                             uint8
#  528  host_neighbourhood_RusswurmHeights                      uint8
#  529  host_neighbourhood_RutledgeHill                         uint8
#  530  host_neighbourhood_SaintJoseph                          uint8
#  531  host_neighbourhood_Salemtown                            uint8
#  532  host_neighbourhood_SantaAna                             uint8
#  533  host_neighbourhood_SantaFe                              uint8
#  534  host_neighbourhood_SeminarySquare                       uint8
#  535  host_neighbourhood_SevenOaks                            uint8
#  536  host_neighbourhood_ShelbyHills                          uint8
#  537  host_neighbourhood_SilverSandsBeach                     uint8
#  538  host_neighbourhood_SkylineVillage                       uint8
#  539  host_neighbourhood_SmithBay                             uint8
#  540  host_neighbourhood_SouthBeach                           uint8
#  541  host_neighbourhood_SouthBoston                          uint8
#  542  host_neighbourhood_SouthColumbus                        uint8
#  543  host_neighbourhood_SouthFirst                           uint8
#  544  host_neighbourhood_SouthHampton                         uint8
#  545  host_neighbourhood_SouthLakeTahoe                       uint8
#  546  host_neighbourhood_SouthLakeUnion                       uint8
#  547  host_neighbourhood_SouthMiamiHeights                    uint8
#  548  host_neighbourhood_SouthNashville                       uint8
#  549  host_neighbourhood_SouthScottsdale                      uint8
#  550  host_neighbourhood_SouthsideHistoricDistrict            uint8
#  551  host_neighbourhood_SouthwestOrlando                     uint8
#  552  host_neighbourhood_SpenceLane                           uint8
#  553  host_neighbourhood_StacySquare                          uint8
#  554  host_neighbourhood_StanfordEstates                      uint8
#  555  host_neighbourhood_StarrPass                            uint8
#  556  host_neighbourhood_StudioCity                           uint8
#  557  host_neighbourhood_SunnyAcres                           uint8
#  558  host_neighbourhood_SunsetView                           uint8
#  559  host_neighbourhood_SylvanHeights                        uint8
#  560  host_neighbourhood_SylvanPark                           uint8
#  561  host_neighbourhood_TMAGThompsonLNMurfreesboroRd         uint8
#  562  host_neighbourhood_TableRock                            uint8
#  563  host_neighbourhood_TalbotsCorner                        uint8
#  564  host_neighbourhood_ThousandOaksEstates                  uint8
#  565  host_neighbourhood_TomorrowsHope                        uint8
#  566  host_neighbourhood_TownhomesofShadowGlen                uint8
#  567  host_neighbourhood_Townsite                             uint8
#  568  host_neighbourhood_Trailwood                            uint8
#  569  host_neighbourhood_TwinLawn                             uint8
#  570  host_neighbourhood_UpperWestSide                        uint8
#  571  host_neighbourhood_UrbandaleNations                     uint8
#  572  host_neighbourhood_Vernon                               uint8
#  573  host_neighbourhood_VillagesofBrentwood                  uint8
#  574  host_neighbourhood_VillagesofLarchwood                  uint8
#  575  host_neighbourhood_Waikiki                              uint8
#  576  host_neighbourhood_WalkersPoint                         uint8
#  577  host_neighbourhood_WatkinsPark                          uint8
#  578  host_neighbourhood_WestEndPark                          uint8
#  579  host_neighbourhood_WestPoplar                           uint8
#  580  host_neighbourhood_WestTownNobleSquare                  uint8
#  581  host_neighbourhood_WestlakeHills                        uint8
#  582  host_neighbourhood_WhisperingHills                      uint8
#  583  host_neighbourhood_Whitebridge                          uint8
#  584  host_neighbourhood_WhitesBend                           uint8
#  585  host_neighbourhood_WhitesCreek                          uint8
#  586  host_neighbourhood_Williamsburg                         uint8
#  587  host_neighbourhood_WindsorPark                          uint8
#  588  host_neighbourhood_WoodberryPark                        uint8
#  589  host_neighbourhood_Woodbine                             uint8
#  590  host_neighbourhood_WoodlandHeights                      uint8
#  591  host_neighbourhood_WoodlandHills                        uint8
#  592  host_neighbourhood_WoodlandinWaverly                    uint8
#  593  host_neighbourhood_Woodycrest                           uint8
#  594  host_neighbourhood_                                     uint8
#  595  host_neighbourhood_NA                                   uint8
#  596  host_verifications_None                                 uint8
#  597  host_verifications_emailphonephotographer               uint8
#  598  host_verifications_emailphonework_email                 uint8
#  599  host_verifications_emailphone                           uint8
#  600  host_verifications_email                                uint8
#  601  host_verifications_phonework_email                      uint8
#  602  host_verifications_phone                                uint8
#  603  host_verifications_nan                                  uint8
#  604  neighbourhood_cleansed_District1                        uint8
#  605  neighbourhood_cleansed_District10                       uint8
#  606  neighbourhood_cleansed_District11                       uint8
#  607  neighbourhood_cleansed_District12                       uint8
#  608  neighbourhood_cleansed_District13                       uint8
#  609  neighbourhood_cleansed_District14                       uint8
#  610  neighbourhood_cleansed_District15                       uint8
#  611  neighbourhood_cleansed_District16                       uint8
#  612  neighbourhood_cleansed_District17                       uint8
#  613  neighbourhood_cleansed_District18                       uint8
#  614  neighbourhood_cleansed_District19                       uint8
#  615  neighbourhood_cleansed_District2                        uint8
#  616  neighbourhood_cleansed_District20                       uint8
#  617  neighbourhood_cleansed_District21                       uint8
#  618  neighbourhood_cleansed_District22                       uint8
#  619  neighbourhood_cleansed_District23                       uint8
#  620  neighbourhood_cleansed_District24                       uint8
#  621  neighbourhood_cleansed_District25                       uint8
#  622  neighbourhood_cleansed_District26                       uint8
#  623  neighbourhood_cleansed_District27                       uint8
#  624  neighbourhood_cleansed_District28                       uint8
#  625  neighbourhood_cleansed_District29                       uint8
#  626  neighbourhood_cleansed_District3                        uint8
#  627  neighbourhood_cleansed_District30                       uint8
#  628  neighbourhood_cleansed_District31                       uint8
#  629  neighbourhood_cleansed_District32                       uint8
#  630  neighbourhood_cleansed_District33                       uint8
#  631  neighbourhood_cleansed_District34                       uint8
#  632  neighbourhood_cleansed_District35                       uint8
#  633  neighbourhood_cleansed_District4                        uint8
#  634  neighbourhood_cleansed_District5                        uint8
#  635  neighbourhood_cleansed_District6                        uint8
#  636  neighbourhood_cleansed_District7                        uint8
#  637  neighbourhood_cleansed_District8                        uint8
#  638  neighbourhood_cleansed_District9                        uint8
#  639  neighbourhood_cleansed_NA                               uint8
#  640  property_type_Barn                                      uint8
#  641  property_type_Bus                                       uint8
#  642  property_type_CamperRV                                  uint8
#  643  property_type_Entirebungalow                            uint8
#  644  property_type_Entirecabin                               uint8
#  645  property_type_Entirechalet                              uint8
#  646  property_type_Entirecondo                               uint8
#  647  property_type_Entirecottage                             uint8
#  648  property_type_Entireguestsuite                          uint8
#  649  property_type_Entireguesthouse                          uint8
#  650  property_type_Entirehome                                uint8
#  651  property_type_Entirehomeapt                             uint8
#  652  property_type_Entireloft                                uint8
#  653  property_type_Entireplace                               uint8
#  654  property_type_Entirerentalunit                          uint8
#  655  property_type_Entireservicedapartment                   uint8
#  656  property_type_Entiretownhouse                           uint8
#  657  property_type_Entirevacationhome                        uint8
#  658  property_type_Entirevilla                               uint8
#  659  property_type_Farmstay                                  uint8
#  660  property_type_Privateroom                               uint8
#  661  property_type_Privateroominbarn                         uint8
#  662  property_type_Privateroominbedandbreakfast              uint8
#  663  property_type_Privateroominbungalow                     uint8
#  664  property_type_Privateroomincamperrv                     uint8
#  665  property_type_Privateroomincasaparticular               uint8
#  666  property_type_Privateroomincondo                        uint8
#  667  property_type_Privateroomincottage                      uint8
#  668  property_type_Privateroominfarmstay                     uint8
#  669  property_type_Privateroominguestsuite                   uint8
#  670  property_type_Privateroominguesthouse                   uint8
#  671  property_type_Privateroominhome                         uint8
#  672  property_type_Privateroominhostel                       uint8
#  673  property_type_Privateroominloft                         uint8
#  674  property_type_Privateroominnaturelodge                  uint8
#  675  property_type_Privateroominreligiousbuilding            uint8
#  676  property_type_Privateroominrentalunit                   uint8
#  677  property_type_Privateroominresort                       uint8
#  678  property_type_Privateroominservicedapartment            uint8
#  679  property_type_Privateroomintownhouse                    uint8
#  680  property_type_Privateroominvilla                        uint8
#  681  property_type_Roominaparthotel                          uint8
#  682  property_type_Roominboutiquehotel                       uint8
#  683  property_type_Roominhotel                               uint8
#  684  property_type_Sharedroomincondo                         uint8
#  685  property_type_Sharedroominhome                          uint8
#  686  property_type_Sharedroominloft                          uint8
#  687  property_type_Sharedroominrentalunit                    uint8
#  688  property_type_Tinyhome                                  uint8
#  689  property_type_NA                                        uint8
#  690  room_type_Entirehomeapt                                 uint8
#  691  room_type_Hotelroom                                     uint8
#  692  room_type_Privateroom                                   uint8
#  693  room_type_Sharedroom                                    uint8
#  694  room_type_NA                                            uint8
#  695  bathrooms_text_0baths                                   uint8
#  696  bathrooms_text_1bath                                    uint8
#  697  bathrooms_text_1privatebath                             uint8
#  698  bathrooms_text_1sharedbath                              uint8
#  699  bathrooms_text_15baths                                  uint8
#  700  bathrooms_text_15sharedbaths                            uint8
#  701  bathrooms_text_10baths                                  uint8
#  702  bathrooms_text_105baths                                 uint8
#  703  bathrooms_text_12baths                                  uint8
#  704  bathrooms_text_125baths                                 uint8
#  705  bathrooms_text_13baths                                  uint8
#  706  bathrooms_text_135baths                                 uint8
#  707  bathrooms_text_14baths                                  uint8
#  708  bathrooms_text_16baths                                  uint8
#  709  bathrooms_text_17baths                                  uint8
#  710  bathrooms_text_175baths                                 uint8
#  711  bathrooms_text_18baths                                  uint8
#  712  bathrooms_text_19baths                                  uint8
#  713  bathrooms_text_2baths                                   uint8
#  714  bathrooms_text_2sharedbaths                             uint8
#  715  bathrooms_text_25baths                                  uint8
#  716  bathrooms_text_25sharedbaths                            uint8
#  717  bathrooms_text_3baths                                   uint8
#  718  bathrooms_text_3sharedbaths                             uint8
#  719  bathrooms_text_35baths                                  uint8
#  720  bathrooms_text_35sharedbaths                            uint8
#  721  bathrooms_text_4baths                                   uint8
#  722  bathrooms_text_4sharedbaths                             uint8
#  723  bathrooms_text_45baths                                  uint8
#  724  bathrooms_text_5baths                                   uint8
#  725  bathrooms_text_55baths                                  uint8
#  726  bathrooms_text_6baths                                   uint8
#  727  bathrooms_text_65baths                                  uint8
#  728  bathrooms_text_7baths                                   uint8
#  729  bathrooms_text_75baths                                  uint8
#  730  bathrooms_text_8baths                                   uint8
#  731  bathrooms_text_85baths                                  uint8
#  732  bathrooms_text_9baths                                   uint8
#  733  bathrooms_text_95baths                                  uint8
#  734  bathrooms_text_Privatehalfbath                          uint8
#  735  bathrooms_text_                                         uint8
#  736  bathrooms_text_NA                                       uint8
# dtypes: float64(35), int32(2), int64(22), uint8(678)
# memory usage: 8.5 MB

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.3)

# Train a LightGBM model on the training data
model = LGBMClassifier()
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = model.predict(X_test)

# Evaluate the performance of the model
print(classification_report(y_test, y_pred, digits=5))
# Out:
#               precision    recall  f1-score   support
#
#          0.0    0.91407   0.89547   0.90467      1081
#          1.0    0.91039   0.92655   0.91840      1239
#
#     accuracy                        0.91207      2320
#    macro avg    0.91223   0.91101   0.91154      2320
# weighted avg    0.91210   0.91207   0.91200      2320

# %%
import lightgbm

plt.rcParams['figure.figsize'] = (5,20)

lightgbm.plot_importance(model, height=0.5)
# Out:
# <AxesSubplot: title={'center': 'Feature importance'}, xlabel='Feature importance', ylabel='Features'>
